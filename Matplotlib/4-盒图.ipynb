# %% [markdown]
# # 基本盒图
#
# sym='*'设置离群点形状
#
# vert=True 设置为竖向展示
#
# ax.boxplot(tang_data,notch=False,sym='*',vert=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import numpy as np

# %%
tang_data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.boxplot(tang_data, notch=False, sym="*", vert=True)

# 刻度值替换为指定字符
ax.set_xticks([y + 1 for y in range(len(tang_data))], ["x1", "x2", "x3"])
ax.set_xlabel("X label")
ax.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')
# /home/sunmy/Jupyter/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) SimHei.
#   func(*args, **kwargs)
# /home/sunmy/Jupyter/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) SimHei.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 设置线条颜色

# %%
fig, ax = plt.subplots(figsize=(8, 6))
bplot = ax.boxplot(tang_data, notch=False, sym="*", vert=True)
print(bplot)
# 刻度值替换为指定字符
ax.set_xticks([y + 1 for y in range(len(tang_data))], ["x1", "x2", "x3"])
ax.set_xlabel("X label")
ax.set_title("Title")

for components in bplot.keys():
    for line in bplot[components]:
        line.set_color("black")
# Out:
# /home/sunmy/Jupyter/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) SimHei.
#   func(*args, **kwargs)
# /home/sunmy/Jupyter/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) SimHei.
#   fig.canvas.print_figure(bytes_io, **kw)
# {'whiskers': [<matplotlib.lines.Line2D object at 0x7f668cf93aa0>, <matplotlib.lines.Line2D object at 0x7f668cf93c80>, <matplotlib.lines.Line2D object at 0x7f668cfccd40>, <matplotlib.lines.Line2D object at 0x7f668cfcd010>, <matplotlib.lines.Line2D object at 0x7f668cfcdfd0>, <matplotlib.lines.Line2D object at 0x7f668cfce2a0>], 'caps': [<matplotlib.lines.Line2D object at 0x7f668cf93f20>, <matplotlib.lines.Line2D object at 0x7f668cfcc260>, <matplotlib.lines.Line2D object at 0x7f668cfcd250>, <matplotlib.lines.Line2D object at 0x7f668cfcd4f0>, <matplotlib.lines.Line2D object at 0x7f668cfce540>, <matplotlib.lines.Line2D object at 0x7f668cfce870>], 'boxes': [<matplotlib.lines.Line2D object at 0x7f668cf93800>, <matplotlib.lines.Line2D object at 0x7f668cfcca70>, <matplotlib.lines.Line2D object at 0x7f668cfcdd00>], 'medians': [<matplotlib.lines.Line2D object at 0x7f668cfcc500>, <matplotlib.lines.Line2D object at 0x7f668cfcd820>, <matplotlib.lines.Line2D object at 0x7f668cfceba0>], 'fliers': [<matplotlib.lines.Line2D object at 0x7f668cfcc7a0>, <matplotlib.lines.Line2D object at 0x7f668cfcda30>, <matplotlib.lines.Line2D object at 0x7f668cfcee70>], 'means': []}

# %% [markdown]
# # 横向画图
#
# **vert=False**代表横向
#
# bplot = ax.boxplot(tang_data,notch=False,sym='*', vert=False)

# %%
fig, ax = plt.subplots(figsize=(8, 6))
bplot = ax.boxplot(tang_data, notch=False, sym="*", vert=False)
print(bplot)
# 刻度值替换为指定字符
ax.set_yticks([y + 1 for y in range(len(tang_data))], ["x1", "x2", "x3"])
ax.set_ylabel("Y label")
ax.set_title("Title")
# Out:
# {'whiskers': [<matplotlib.lines.Line2D object at 0x7f668d033e00>, <matplotlib.lines.Line2D object at 0x7f668f130110>, <matplotlib.lines.Line2D object at 0x7f668f131220>, <matplotlib.lines.Line2D object at 0x7f668f131520>, <matplotlib.lines.Line2D object at 0x7f668f1325d0>, <matplotlib.lines.Line2D object at 0x7f668f1328d0>], 'caps': [<matplotlib.lines.Line2D object at 0x7f668f130380>, <matplotlib.lines.Line2D object at 0x7f668f130680>, <matplotlib.lines.Line2D object at 0x7f668f1317f0>, <matplotlib.lines.Line2D object at 0x7f668f131ac0>, <matplotlib.lines.Line2D object at 0x7f668f132ae0>, <matplotlib.lines.Line2D object at 0x7f668f132db0>], 'boxes': [<matplotlib.lines.Line2D object at 0x7f668d033b30>, <matplotlib.lines.Line2D object at 0x7f668f130ef0>, <matplotlib.lines.Line2D object at 0x7f668f1322d0>], 'medians': [<matplotlib.lines.Line2D object at 0x7f668f1309b0>, <matplotlib.lines.Line2D object at 0x7f668f131d90>, <matplotlib.lines.Line2D object at 0x7f668f1330b0>], 'fliers': [<matplotlib.lines.Line2D object at 0x7f668f130c50>, <matplotlib.lines.Line2D object at 0x7f668f132000>, <matplotlib.lines.Line2D object at 0x7f668f133380>], 'means': []}
# Text(0.5, 1.0, 'Title')
# /home/sunmy/Jupyter/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) SimHei.
#   func(*args, **kwargs)
# /home/sunmy/Jupyter/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) SimHei.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 小提琴图violinplot

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
tang_data = [np.random.normal(0, std, 100) for std in range(6, 10)]
axes[0].violinplot(tang_data, showmeans=False, showmedians=True)
axes[0].set_title("violin plot")

axes[1].boxplot(tang_data)
axes[1].set_title("box plot")

for ax in axes:
    ax.yaxis.grid(True)
    ax.set_xticks([y + 1 for y in range(len(tang_data))], ["a", "b", "c", "d"])
# Out:
# /home/sunmy/Jupyter/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) SimHei.
#   func(*args, **kwargs)
# /home/sunmy/Jupyter/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) SimHei.
#   fig.canvas.print_figure(bytes_io, **kw)
