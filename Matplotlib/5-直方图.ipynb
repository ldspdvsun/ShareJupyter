# %%
import random

import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.normal(0, 20, 1000)
bins = np.arange(-100, 100, 5)

# %% [markdown]
# # 直方图

# %%
plg, ax = plt.subplots()
ax.hist(data, bins=bins)
ax.set_xlim(min(data), max(data))
# Out:
# (-61.14835956926682, 90.08878793064206)
# /home/sunmy/Jupyter/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) SimHei.
#   func(*args, **kwargs)
# /home/sunmy/Jupyter/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) SimHei.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data1 = [random.gauss(15, 10) for i in range(500)]
data2 = [random.gauss(5, 10) for i in range(500)]
plg, ax = plt.subplots()
ax.hist(data1, bins=bins, label="class1", alpha=0.3)
ax.hist(data2, bins=bins, label="class2", alpha=0.8)
ax.set_xlim(min(min(data1), min(data2)), max(max(data1), max(data2)))
ax.legend(loc="upper left")
